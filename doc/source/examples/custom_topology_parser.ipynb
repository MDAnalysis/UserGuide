# %% [markdown]
# # Writing your own topology parser
#
# How to write your own topology parser for a custom file format.
#
# **Last updated:** February 2020
#
# **Minimum version of MDAnalysis:** 0.17.0
#
# **Packages required:**
#
# * MDAnalysis [[1, 2]](#References)
# * MDAnalysisTests
